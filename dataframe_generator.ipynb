# %% [markdown]
# # Dataframe Generator
# This notebook aims to generate train and test dataframe from the raw images in the directory using hand-crafted features, such as
# - average red in the image (continuous numeric number)
# - average green in the image (continuous numeric number)
# - average blue in the image (continuous numeric number)
# - average saturation in the image (continuous numeric number)
# - contrast of the image (continuous numeric number)
# - angular second moment (ASM) of the image (continuous numeric number)
# - homogeneity of the image (continuous numeric number)
#
# and also `image directory path` and `image label`.

# %% [markdown]
# ### Note
# You don't have to run this again in your machine. All the results are already saved as `train_images_features.csv` and `test_images_features.csv` that can be used to the machine learning models, directly or maybe with several extra preprocessing.
#
# However, if you still want to try, you need to know that **it might take some time and resources, and possibly bring your computer down if you don't have enough resources**.

# %%
import glob
import pandas as pd

from feature_extractor import extract_images_features

# %%
def generate_train(path, train_label):
    df_list = []
    for label in train_label:
        print("\nProcessing label {}".format(label))
        
        image_paths = glob.glob(path + "{}/*".format(label))
        N = len(image_paths)
        df_list.append(extract_images_features(image_paths, [label] * N))
    
    return pd.concat(df_list)

# %%
def generate_test(path, children_path, test_label_map):
    image_paths = glob.glob(path + children_path)
    N = len(image_paths)
    
    labels = []
    for path in image_paths:
        file_name = path.split('/')[-1].lower()
        for label in test_label_map.keys():
            if file_name.startswith(label):
                labels.append(test_label_map[label])
                break
    
    return extract_images_features(image_paths, labels)

# %%
train_label = ["cloudy", "foggy", "rainy", "shine", "sunrise"]
train_df = generate_train("./dataset/", train_label)

display(train_df.head())
train_df.to_csv("train_images_features.csv", index_label="id")
# Out:
# Processing label cloudy
# Processing 1 / 300 images
# Processing 2 / 300 images
# Processing 3 / 300 images
# Processing 4 / 300 images
# Processing 5 / 300 images
# Processing 6 / 300 images
# Processing 7 / 300 images
# Processing 8 / 300 images
# Processing 9 / 300 images
# Processing 10 / 300 images
# Processing 11 / 300 images
# Processing 12 / 300 images
# Processing 13 / 300 images
# Processing 14 / 300 images
# Processing 15 / 300 images
# Processing 16 / 300 images
# Processing 17 / 300 images
# Processing 18 / 300 images
# Processing 19 / 300 images
# Processing 20 / 300 images
# Processing 21 / 300 images
# Processing 22 / 300 images
# Processing 23 / 300 images
# Processing 24 / 300 images
# Processing 25 / 300 images
# Processing 26 / 300 images
# Processing 27 / 300 images
# Processing 28 / 300 images
# Processing 29 / 300 images
# Processing 30 / 300 images
# Processing 31 / 300 images
# Processing 32 / 300 images
# Processing 33 / 300 images
# Processing 34 / 300 images
# Processing 35 / 300 images
# Processing 36 / 300 images
# Processing 37 / 300 images
# Processing 38 / 300 images
# Processing 39 / 300 images
# Processing 40 / 300 images
# Processing 41 / 300 images
# Processing 42 / 300 images
# Processing 43 / 300 images
# Processing 44 / 300 images
# Processing 45 / 300 images
# Processing 46 / 300 images
# Processing 47 / 300 images
# Processing 48 / 300 images
# Processing 49 / 300 images
# Processing 50 / 300 images
# Processing 51 / 300 images
# Processing 52 / 300 images
# Processing 53 / 300 images
# Processing 54 / 300 images
# Processing 55 / 300 images
# Processing 56 / 300 images
# Processing 57 / 300 images
# Processing 58 / 300 images
# Processing 59 / 300 images
# Processing 60 / 300 images
# Processing 61 / 300 images
# Processing 62 / 300 images
# Processing 63 / 300 images
# Processing 64 / 300 images
# Processing 65 / 300 images
# Processing 66 / 300 images
# Processing 67 / 300 images
# Processing 68 / 300 images
# Processing 69 / 300 images
# Processing 70 / 300 images
# Processing 71 / 300 images
# Processing 72 / 300 images
# Processing 73 / 300 images
# Processing 74 / 300 images
# Processing 75 / 300 images
# Processing 76 / 300 images
# Processing 77 / 300 images
# Processing 78 / 300 images
# Processing 79 / 300 images
# Processing 80 / 300 images
# Processing 81 / 300 images
# Processing 82 / 300 images
# Processing 83 / 300 images
# Processing 84 / 300 images
# Processing 85 / 300 images
# Processing 86 / 300 images
# Processing 87 / 300 images
# Processing 88 / 300 images
# Processing 89 / 300 images
# Processing 90 / 300 images
# Processing 91 / 300 images
# Processing 92 / 300 images
# Processing 93 / 300 images
# Processing 94 / 300 images
# Processing 95 / 300 images
# Processing 96 / 300 images
# Processing 97 / 300 images
# Processing 98 / 300 images
# Processing 99 / 300 images
# Processing 100 / 300 images
# Processing 101 / 300 images
# Processing 102 / 300 images
# Processing 103 / 300 images
# Processing 104 / 300 images
# Processing 105 / 300 images
# Processing 106 / 300 images
# Processing 107 / 300 images
# Processing 108 / 300 images
# Processing 109 / 300 images
# Processing 110 / 300 images
# Processing 111 / 300 images
# Processing 112 / 300 images
# Processing 113 / 300 images
# Processing 114 / 300 images
# Processing 115 / 300 images
# Processing 116 / 300 images
# Processing 117 / 300 images
# Processing 118 / 300 images
# Processing 119 / 300 images
# Processing 120 / 300 images
# Processing 121 / 300 images
# Processing 122 / 300 images
# Processing 123 / 300 images
# Processing 124 / 300 images
# Processing 125 / 300 images
# Processing 126 / 300 images
# Processing 127 / 300 images
# Processing 128 / 300 images
# Processing 129 / 300 images
# Processing 130 / 300 images
# Processing 131 / 300 images
# Processing 132 / 300 images
# Processing 133 / 300 images
# Processing 134 / 300 images
# Processing 135 / 300 images
# Processing 136 / 300 images
# Processing 137 / 300 images
# Processing 138 / 300 images
# Processing 139 / 300 images
# Processing 140 / 300 images
# Processing 141 / 300 images
# Processing 142 / 300 images
# Processing 143 / 300 images
# Processing 144 / 300 images
# Processing 145 / 300 images
# Processing 146 / 300 images
# Processing 147 / 300 images
# Processing 148 / 300 images
# Processing 149 / 300 images
# Processing 150 / 300 images
# Processing 151 / 300 images
# Processing 152 / 300 images
# Processing 153 / 300 images
# Processing 154 / 300 images
# Processing 155 / 300 images
# Processing 156 / 300 images
# Processing 157 / 300 images
# Processing 158 / 300 images
# Processing 159 / 300 images
# Processing 160 / 300 images
# Processing 161 / 300 images
# Processing 162 / 300 images
# Processing 163 / 300 images
# Processing 164 / 300 images
# Processing 165 / 300 images
# Processing 166 / 300 images
# Processing 167 / 300 images
# Processing 168 / 300 images
# Processing 169 / 300 images
# Processing 170 / 300 images
# Processing 171 / 300 images
# Processing 172 / 300 images
# Processing 173 / 300 images
# Processing 174 / 300 images
# Processing 175 / 300 images
# Processing 176 / 300 images
# Processing 177 / 300 images
# Processing 178 / 300 images
# Processing 179 / 300 images
# Processing 180 / 300 images
# Processing 181 / 300 images
# Processing 182 / 300 images
# Processing 183 / 300 images
# Processing 184 / 300 images
# Processing 185 / 300 images
# Processing 186 / 300 images
# Processing 187 / 300 images
# Processing 188 / 300 images
# Processing 189 / 300 images
# Processing 190 / 300 images
# Processing 191 / 300 images
# Processing 192 / 300 images
# Processing 193 / 300 images
# Processing 194 / 300 images
# Processing 195 / 300 images
# Processing 196 / 300 images
# Processing 197 / 300 images
# Processing 198 / 300 images
# Processing 199 / 300 images
# Processing 200 / 300 images
# Processing 201 / 300 images
# Processing 202 / 300 images
# Processing 203 / 300 images
# Processing 204 / 300 images
# Processing 205 / 300 images
# Processing 206 / 300 images
# Processing 207 / 300 images
# Processing 208 / 300 images
# Processing 209 / 300 images
# Processing 210 / 300 images
# Processing 211 / 300 images
# Processing 212 / 300 images
# Processing 213 / 300 images
# Processing 214 / 300 images
# Processing 215 / 300 images
# Processing 216 / 300 images
# Processing 217 / 300 images
# Processing 218 / 300 images
# Processing 219 / 300 images
# Processing 220 / 300 images
# Processing 221 / 300 images
# Processing 222 / 300 images
# Processing 223 / 300 images
# Processing 224 / 300 images
# Processing 225 / 300 images
# Processing 226 / 300 images
# Processing 227 / 300 images
# Processing 228 / 300 images
# Processing 229 / 300 images
# Processing 230 / 300 images
# Processing 231 / 300 images
# Processing 232 / 300 images
# Processing 233 / 300 images
# Processing 234 / 300 images
# Processing 235 / 300 images
# Processing 236 / 300 images
# Processing 237 / 300 images
# Processing 238 / 300 images
# Processing 239 / 300 images
# Processing 240 / 300 images
# Processing 241 / 300 images
# Processing 242 / 300 images
# Processing 243 / 300 images
# Processing 244 / 300 images
# Processing 245 / 300 images
# Processing 246 / 300 images
# Processing 247 / 300 images
# Processing 248 / 300 images
# Processing 249 / 300 images
# Processing 250 / 300 images
# Processing 251 / 300 images
# Processing 252 / 300 images
# Processing 253 / 300 images
# Processing 254 / 300 images
# Processing 255 / 300 images
# Processing 256 / 300 images
# Processing 257 / 300 images
# Processing 258 / 300 images
# Processing 259 / 300 images
# Processing 260 / 300 images
# Processing 261 / 300 images
# Processing 262 / 300 images
# Processing 263 / 300 images
# Processing 264 / 300 images
# Processing 265 / 300 images
# Processing 266 / 300 images
# Processing 267 / 300 images
# Processing 268 / 300 images
# Processing 269 / 300 images
# Processing 270 / 300 images
# Processing 271 / 300 images
# Processing 272 / 300 images
# Processing 273 / 300 images
# Processing 274 / 300 images
# Processing 275 / 300 images
# Processing 276 / 300 images
# Processing 277 / 300 images
# Processing 278 / 300 images
# Processing 279 / 300 images
# Processing 280 / 300 images
# Processing 281 / 300 images
# Processing 282 / 300 images
# Processing 283 / 300 images
# Processing 284 / 300 images
# Processing 285 / 300 images
# Processing 286 / 300 images
# Processing 287 / 300 images
# Processing 288 / 300 images
# Processing 289 / 300 images
# Processing 290 / 300 images
# Processing 291 / 300 images
# Processing 292 / 300 images
# Processing 293 / 300 images
# Processing 294 / 300 images
# Processing 295 / 300 images
# Processing 296 / 300 images
# Processing 297 / 300 images
# Processing 298 / 300 images
# Processing 299 / 300 images
# Processing 300 / 300 images
#
# Processing label foggy
# Processing 1 / 300 images
# Processing 2 / 300 images
# Processing 3 / 300 images
# Processing 4 / 300 images
# Processing 5 / 300 images
# Processing 6 / 300 images
# Processing 7 / 300 images
# Processing 8 / 300 images
# Processing 9 / 300 images
# Processing 10 / 300 images
# Processing 11 / 300 images
# Processing 12 / 300 images
# Processing 13 / 300 images
# Processing 14 / 300 images
# Processing 15 / 300 images
# Processing 16 / 300 images
# Processing 17 / 300 images
# Processing 18 / 300 images
# Processing 19 / 300 images
# Processing 20 / 300 images
# Processing 21 / 300 images
# Processing 22 / 300 images
# Processing 23 / 300 images
# Processing 24 / 300 images
# Processing 25 / 300 images
# Processing 26 / 300 images
# Processing 27 / 300 images
# Processing 28 / 300 images
# Processing 29 / 300 images
# Processing 30 / 300 images
# Processing 31 / 300 images
# Processing 32 / 300 images
# Processing 33 / 300 images
# Processing 34 / 300 images
# Processing 35 / 300 images
# Processing 36 / 300 images
# Processing 37 / 300 images
# Processing 38 / 300 images
# Processing 39 / 300 images
# Processing 40 / 300 images
# Processing 41 / 300 images
# Processing 42 / 300 images
# Processing 43 / 300 images
# Processing 44 / 300 images
# Processing 45 / 300 images
# Processing 46 / 300 images
# Processing 47 / 300 images
# Processing 48 / 300 images
# Processing 49 / 300 images
# Processing 50 / 300 images
# Processing 51 / 300 images
# Processing 52 / 300 images
# Processing 53 / 300 images
# Processing 54 / 300 images
# Processing 55 / 300 images
# Processing 56 / 300 images
# Processing 57 / 300 images
# Processing 58 / 300 images
# Processing 59 / 300 images
# Processing 60 / 300 images
# Processing 61 / 300 images
# Processing 62 / 300 images
# Processing 63 / 300 images
# Processing 64 / 300 images
# Processing 65 / 300 images
# Processing 66 / 300 images
# Processing 67 / 300 images
# Processing 68 / 300 images
# Processing 69 / 300 images
# Processing 70 / 300 images
# Processing 71 / 300 images
# Processing 72 / 300 images
# Processing 73 / 300 images
# Processing 74 / 300 images
# Processing 75 / 300 images
# Processing 76 / 300 images
# Processing 77 / 300 images
# Processing 78 / 300 images
# Processing 79 / 300 images
# Processing 80 / 300 images
# Processing 81 / 300 images
# Processing 82 / 300 images
# Processing 83 / 300 images
# Processing 84 / 300 images
# Processing 85 / 300 images
# Processing 86 / 300 images
# Processing 87 / 300 images
# Processing 88 / 300 images
# Processing 89 / 300 images
# Processing 90 / 300 images
# Processing 91 / 300 images
# Processing 92 / 300 images
# Processing 93 / 300 images
# Processing 94 / 300 images
# Processing 95 / 300 images
# Processing 96 / 300 images
# Processing 97 / 300 images
# Processing 98 / 300 images
# Processing 99 / 300 images
# Processing 100 / 300 images
# Processing 101 / 300 images
# Processing 102 / 300 images
# Processing 103 / 300 images
# Processing 104 / 300 images
# Processing 105 / 300 images
# Processing 106 / 300 images
# Processing 107 / 300 images
# Processing 108 / 300 images
# Processing 109 / 300 images
# Processing 110 / 300 images
# Processing 111 / 300 images
# Processing 112 / 300 images
# Processing 113 / 300 images
# Processing 114 / 300 images
# Processing 115 / 300 images
# Processing 116 / 300 images
# Processing 117 / 300 images
# Processing 118 / 300 images
# Processing 119 / 300 images
# Processing 120 / 300 images
# Processing 121 / 300 images
# Processing 122 / 300 images
# Processing 123 / 300 images
# Processing 124 / 300 images
# Processing 125 / 300 images
# Processing 126 / 300 images
# Processing 127 / 300 images
# Processing 128 / 300 images
# Processing 129 / 300 images
# Processing 130 / 300 images
# Processing 131 / 300 images
# Processing 132 / 300 images
# Processing 133 / 300 images
# Processing 134 / 300 images
# Processing 135 / 300 images
# Processing 136 / 300 images
# Processing 137 / 300 images
# Processing 138 / 300 images
# Processing 139 / 300 images
# Processing 140 / 300 images
# Processing 141 / 300 images
# Processing 142 / 300 images
# Processing 143 / 300 images
# Processing 144 / 300 images
# Processing 145 / 300 images
# Processing 146 / 300 images
# Processing 147 / 300 images
# Processing 148 / 300 images
# Processing 149 / 300 images
# Processing 150 / 300 images
# Processing 151 / 300 images
# Processing 152 / 300 images
# Processing 153 / 300 images
# Processing 154 / 300 images
# Processing 155 / 300 images
# Processing 156 / 300 images
# Processing 157 / 300 images
# Processing 158 / 300 images
# Processing 159 / 300 images
# Processing 160 / 300 images
# Processing 161 / 300 images
# Processing 162 / 300 images
# Processing 163 / 300 images
# Processing 164 / 300 images
# Processing 165 / 300 images
# Processing 166 / 300 images
# Processing 167 / 300 images
# Processing 168 / 300 images
# Processing 169 / 300 images
# Processing 170 / 300 images
# Processing 171 / 300 images
# Processing 172 / 300 images
# Processing 173 / 300 images
# Processing 174 / 300 images
# Processing 175 / 300 images
# Processing 176 / 300 images
# Processing 177 / 300 images
# Processing 178 / 300 images
# Processing 179 / 300 images
# Processing 180 / 300 images
# Processing 181 / 300 images
# Processing 182 / 300 images
# Processing 183 / 300 images
# Processing 184 / 300 images
# Processing 185 / 300 images
# Processing 186 / 300 images
# Processing 187 / 300 images
# Processing 188 / 300 images
# Processing 189 / 300 images
# Processing 190 / 300 images
# Processing 191 / 300 images
# Processing 192 / 300 images
# Processing 193 / 300 images
# Processing 194 / 300 images
# Processing 195 / 300 images
# Processing 196 / 300 images
# Processing 197 / 300 images
# Processing 198 / 300 images
# Processing 199 / 300 images
# Processing 200 / 300 images
# Processing 201 / 300 images
# Processing 202 / 300 images
# Processing 203 / 300 images
# Processing 204 / 300 images
# Processing 205 / 300 images
# Processing 206 / 300 images
# Processing 207 / 300 images
# Processing 208 / 300 images
# Processing 209 / 300 images
# Processing 210 / 300 images
# Processing 211 / 300 images
# Processing 212 / 300 images
# Processing 213 / 300 images
# Processing 214 / 300 images
# Processing 215 / 300 images
# Processing 216 / 300 images
# Processing 217 / 300 images
# Processing 218 / 300 images
# Processing 219 / 300 images
# Processing 220 / 300 images
# Processing 221 / 300 images
# Processing 222 / 300 images
# Processing 223 / 300 images
# Processing 224 / 300 images
# Processing 225 / 300 images
# Processing 226 / 300 images
# Processing 227 / 300 images
# Processing 228 / 300 images
# Processing 229 / 300 images
# Processing 230 / 300 images
# Processing 231 / 300 images
# Processing 232 / 300 images
# Processing 233 / 300 images
# Processing 234 / 300 images
# Processing 235 / 300 images
# Processing 236 / 300 images
# Processing 237 / 300 images
# Processing 238 / 300 images
# Processing 239 / 300 images
# Processing 240 / 300 images
# Processing 241 / 300 images
# Processing 242 / 300 images
# Processing 243 / 300 images
# Processing 244 / 300 images
# Processing 245 / 300 images
# Processing 246 / 300 images
# Processing 247 / 300 images
# Processing 248 / 300 images
# Processing 249 / 300 images
# Processing 250 / 300 images
# Processing 251 / 300 images
# Processing 252 / 300 images
# Processing 253 / 300 images
# Processing 254 / 300 images
# Processing 255 / 300 images
# Processing 256 / 300 images
# Processing 257 / 300 images
# Processing 258 / 300 images
# Processing 259 / 300 images
# Processing 260 / 300 images
# Processing 261 / 300 images
# Processing 262 / 300 images
# Processing 263 / 300 images
# Processing 264 / 300 images
# Processing 265 / 300 images
# Processing 266 / 300 images
# Processing 267 / 300 images
# Processing 268 / 300 images
# Processing 269 / 300 images
# Processing 270 / 300 images
# Processing 271 / 300 images
# Processing 272 / 300 images
# Processing 273 / 300 images
# Processing 274 / 300 images
# Processing 275 / 300 images
# Processing 276 / 300 images
# Processing 277 / 300 images
# Processing 278 / 300 images
# Processing 279 / 300 images
# Processing 280 / 300 images
# Processing 281 / 300 images
# Processing 282 / 300 images
# Processing 283 / 300 images
# Processing 284 / 300 images
# Processing 285 / 300 images
# Processing 286 / 300 images
# Processing 287 / 300 images
# Processing 288 / 300 images
# Processing 289 / 300 images
# Processing 290 / 300 images
# Processing 291 / 300 images
# Processing 292 / 300 images
# Processing 293 / 300 images
# Processing 294 / 300 images
# Processing 295 / 300 images
# Processing 296 / 300 images
# Processing 297 / 300 images
# Processing 298 / 300 images
# Processing 299 / 300 images
# Processing 300 / 300 images
#
# Processing label rainy
# Processing 1 / 300 images
# Processing 2 / 300 images
# Processing 3 / 300 images
# Processing 4 / 300 images
# Processing 5 / 300 images
# Processing 6 / 300 images
# Processing 7 / 300 images
# Processing 8 / 300 images
# Processing 9 / 300 images
# Processing 10 / 300 images
# Processing 11 / 300 images
# Processing 12 / 300 images
# Processing 13 / 300 images
# Processing 14 / 300 images
# Processing 15 / 300 images
# Processing 16 / 300 images
# Processing 17 / 300 images
# Processing 18 / 300 images
# Processing 19 / 300 images
# Processing 20 / 300 images
# Processing 21 / 300 images
# Processing 22 / 300 images
# Processing 23 / 300 images
# Processing 24 / 300 images
# Processing 25 / 300 images
# Processing 26 / 300 images
# Processing 27 / 300 images
# Processing 28 / 300 images
# Processing 29 / 300 images
# Processing 30 / 300 images
# Processing 31 / 300 images
# Processing 32 / 300 images
# Processing 33 / 300 images
# Processing 34 / 300 images
# Processing 35 / 300 images
# Processing 36 / 300 images
# Processing 37 / 300 images
# Processing 38 / 300 images
# Processing 39 / 300 images
# Processing 40 / 300 images
# Processing 41 / 300 images
# Processing 42 / 300 images
# Processing 43 / 300 images
# Processing 44 / 300 images
# Processing 45 / 300 images
# Processing 46 / 300 images
# Processing 47 / 300 images
# Processing 48 / 300 images
# Processing 49 / 300 images
# Processing 50 / 300 images
# Processing 51 / 300 images
# Processing 52 / 300 images
# Processing 53 / 300 images
# Processing 54 / 300 images
# Processing 55 / 300 images
# Processing 56 / 300 images
# Processing 57 / 300 images
# Processing 58 / 300 images
# Processing 59 / 300 images
# Processing 60 / 300 images
# Processing 61 / 300 images
# Processing 62 / 300 images
# Processing 63 / 300 images
# Processing 64 / 300 images
# Processing 65 / 300 images
# Processing 66 / 300 images
# Processing 67 / 300 images
# Processing 68 / 300 images
# Processing 69 / 300 images
# Processing 70 / 300 images
# Processing 71 / 300 images
# Processing 72 / 300 images
# Processing 73 / 300 images
# Processing 74 / 300 images
# Processing 75 / 300 images
# Processing 76 / 300 images
# Processing 77 / 300 images
# Processing 78 / 300 images
# Processing 79 / 300 images
# Processing 80 / 300 images
# Processing 81 / 300 images
# Processing 82 / 300 images
# Processing 83 / 300 images
# Processing 84 / 300 images
# Processing 85 / 300 images
# Processing 86 / 300 images
# Processing 87 / 300 images
# Processing 88 / 300 images
# Processing 89 / 300 images
# Processing 90 / 300 images
# Processing 91 / 300 images
# Processing 92 / 300 images
# Processing 93 / 300 images
# Processing 94 / 300 images
# Processing 95 / 300 images
# Processing 96 / 300 images
# Processing 97 / 300 images
# Processing 98 / 300 images
# Processing 99 / 300 images
# Processing 100 / 300 images
# Processing 101 / 300 images
# Processing 102 / 300 images
# Processing 103 / 300 images
# Processing 104 / 300 images
# Processing 105 / 300 images
# Processing 106 / 300 images
# Processing 107 / 300 images
# Processing 108 / 300 images
# Processing 109 / 300 images
# Processing 110 / 300 images
# Processing 111 / 300 images
# Processing 112 / 300 images
# Processing 113 / 300 images
# Processing 114 / 300 images
# Processing 115 / 300 images
# Processing 116 / 300 images
# Processing 117 / 300 images
# Processing 118 / 300 images
# Processing 119 / 300 images
# Processing 120 / 300 images
# Processing 121 / 300 images
# Processing 122 / 300 images
# Processing 123 / 300 images
# Processing 124 / 300 images
# Processing 125 / 300 images
# Processing 126 / 300 images
# Processing 127 / 300 images
# Processing 128 / 300 images
# Processing 129 / 300 images
# Processing 130 / 300 images
# Processing 131 / 300 images
# Processing 132 / 300 images
# Processing 133 / 300 images
# Processing 134 / 300 images
# Processing 135 / 300 images
# Processing 136 / 300 images
# Processing 137 / 300 images
# Processing 138 / 300 images
# Processing 139 / 300 images
# Processing 140 / 300 images
# Processing 141 / 300 images
# Processing 142 / 300 images
# Processing 143 / 300 images
# Processing 144 / 300 images
# Processing 145 / 300 images
# Processing 146 / 300 images
# Processing 147 / 300 images
# Processing 148 / 300 images
# Processing 149 / 300 images
# Processing 150 / 300 images
# Processing 151 / 300 images
# Processing 152 / 300 images
# Processing 153 / 300 images
# Processing 154 / 300 images
# Processing 155 / 300 images
# Processing 156 / 300 images
# Processing 157 / 300 images
# Processing 158 / 300 images
# Processing 159 / 300 images
# Processing 160 / 300 images
# Processing 161 / 300 images
# Processing 162 / 300 images
# Processing 163 / 300 images
# Processing 164 / 300 images
# Processing 165 / 300 images
# Processing 166 / 300 images
# Processing 167 / 300 images
# Processing 168 / 300 images
# Processing 169 / 300 images
# Processing 170 / 300 images
# Processing 171 / 300 images
# Processing 172 / 300 images
# Processing 173 / 300 images
# Processing 174 / 300 images
# Processing 175 / 300 images
# Processing 176 / 300 images
# Processing 177 / 300 images
# Processing 178 / 300 images
# Processing 179 / 300 images
# Processing 180 / 300 images
# Processing 181 / 300 images
# Processing 182 / 300 images
# Processing 183 / 300 images
# Processing 184 / 300 images
# Processing 185 / 300 images
# Processing 186 / 300 images
# Processing 187 / 300 images
# Processing 188 / 300 images
# Processing 189 / 300 images
# Processing 190 / 300 images
# Processing 191 / 300 images
# Processing 192 / 300 images
# Processing 193 / 300 images
# Processing 194 / 300 images
# Processing 195 / 300 images
# Processing 196 / 300 images
# Processing 197 / 300 images
# Processing 198 / 300 images
# Processing 199 / 300 images
# Processing 200 / 300 images
# Processing 201 / 300 images
# Processing 202 / 300 images
# Processing 203 / 300 images
# Processing 204 / 300 images
# Processing 205 / 300 images
# Processing 206 / 300 images
# Processing 207 / 300 images
# Processing 208 / 300 images
# Processing 209 / 300 images
# Processing 210 / 300 images
# Processing 211 / 300 images
# Processing 212 / 300 images
# Processing 213 / 300 images
# Processing 214 / 300 images
# Processing 215 / 300 images
# Processing 216 / 300 images
# Processing 217 / 300 images
# Processing 218 / 300 images
# Processing 219 / 300 images
# Processing 220 / 300 images
# Processing 221 / 300 images
# Processing 222 / 300 images
# Processing 223 / 300 images
# Processing 224 / 300 images
# Processing 225 / 300 images
# Processing 226 / 300 images
# Processing 227 / 300 images
# Processing 228 / 300 images
# Processing 229 / 300 images
# Processing 230 / 300 images
# Processing 231 / 300 images
# Processing 232 / 300 images
# Processing 233 / 300 images
# Processing 234 / 300 images
# Processing 235 / 300 images
# Processing 236 / 300 images
# Processing 237 / 300 images
# Processing 238 / 300 images
# Processing 239 / 300 images
# Processing 240 / 300 images
# Processing 241 / 300 images
# Processing 242 / 300 images
# Processing 243 / 300 images
# Processing 244 / 300 images
# Processing 245 / 300 images
# Processing 246 / 300 images
# Processing 247 / 300 images
# Processing 248 / 300 images
# Processing 249 / 300 images
# Processing 250 / 300 images
# Processing 251 / 300 images
# Processing 252 / 300 images
# Processing 253 / 300 images
# Processing 254 / 300 images
# Processing 255 / 300 images
# Processing 256 / 300 images
# Processing 257 / 300 images
# Processing 258 / 300 images
# Processing 259 / 300 images
# Processing 260 / 300 images
# Processing 261 / 300 images
# Processing 262 / 300 images
# Processing 263 / 300 images
# Processing 264 / 300 images
# Processing 265 / 300 images
# Processing 266 / 300 images
# Processing 267 / 300 images
# Processing 268 / 300 images
# Processing 269 / 300 images
# Processing 270 / 300 images
# Processing 271 / 300 images
# Processing 272 / 300 images
# Processing 273 / 300 images
# Processing 274 / 300 images
# Processing 275 / 300 images
# Processing 276 / 300 images
# Processing 277 / 300 images
# Processing 278 / 300 images
# Processing 279 / 300 images
# Processing 280 / 300 images
# Processing 281 / 300 images
# Processing 282 / 300 images
# Processing 283 / 300 images
# Processing 284 / 300 images
# Processing 285 / 300 images
# Processing 286 / 300 images
# Processing 287 / 300 images
# Processing 288 / 300 images
# Processing 289 / 300 images
# Processing 290 / 300 images
# Processing 291 / 300 images
# Processing 292 / 300 images
# Processing 293 / 300 images
# Processing 294 / 300 images
# Processing 295 / 300 images
# Processing 296 / 300 images
# Processing 297 / 300 images
# Processing 298 / 300 images
# Processing 299 / 300 images
# Processing 300 / 300 images
#
# Processing label shine
# Processing 1 / 250 images
# Processing 2 / 250 images
# Processing 3 / 250 images
# Processing 4 / 250 images
# Processing 5 / 250 images
# Processing 6 / 250 images
# Processing 7 / 250 images
# Processing 8 / 250 images
# Processing 9 / 250 images
# Processing 10 / 250 images
# Processing 11 / 250 images
# Processing 12 / 250 images
# Processing 13 / 250 images
# Processing 14 / 250 images
# Processing 15 / 250 images
# Processing 16 / 250 images
# Processing 17 / 250 images
# Processing 18 / 250 images
# Processing 19 / 250 images
# Processing 20 / 250 images
# Processing 21 / 250 images
# Processing 22 / 250 images
# Processing 23 / 250 images
# Processing 24 / 250 images
# Processing 25 / 250 images
# Processing 26 / 250 images
# Processing 27 / 250 images
# Processing 28 / 250 images
# Processing 29 / 250 images
# Processing 30 / 250 images
# Processing 31 / 250 images
# Processing 32 / 250 images
# Processing 33 / 250 images
# Processing 34 / 250 images
# Processing 35 / 250 images
# Processing 36 / 250 images
# Processing 37 / 250 images
# Processing 38 / 250 images
# Processing 39 / 250 images
# Processing 40 / 250 images
# Processing 41 / 250 images
# Processing 42 / 250 images
# Processing 43 / 250 images
# Processing 44 / 250 images
# Processing 45 / 250 images
# Processing 46 / 250 images
# Processing 47 / 250 images
# Processing 48 / 250 images
# Processing 49 / 250 images
# Processing 50 / 250 images
# Processing 51 / 250 images
# Processing 52 / 250 images
# Processing 53 / 250 images
# Processing 54 / 250 images
# Processing 55 / 250 images
# Processing 56 / 250 images
# Processing 57 / 250 images
# Processing 58 / 250 images
# Processing 59 / 250 images
# Processing 60 / 250 images
# Processing 61 / 250 images
# Processing 62 / 250 images
# Processing 63 / 250 images
# Processing 64 / 250 images
# Processing 65 / 250 images
# Processing 66 / 250 images
# Processing 67 / 250 images
# Processing 68 / 250 images
# Processing 69 / 250 images
# Processing 70 / 250 images
# Processing 71 / 250 images
# Processing 72 / 250 images
# Processing 73 / 250 images
# Processing 74 / 250 images
# Processing 75 / 250 images
# Processing 76 / 250 images
# Processing 77 / 250 images
# Processing 78 / 250 images
# Processing 79 / 250 images
# Processing 80 / 250 images
# Processing 81 / 250 images
# Processing 82 / 250 images
# Processing 83 / 250 images
# Processing 84 / 250 images
# Processing 85 / 250 images
# Processing 86 / 250 images
# Processing 87 / 250 images
# Processing 88 / 250 images
# Processing 89 / 250 images
# Processing 90 / 250 images
# Processing 91 / 250 images
# Processing 92 / 250 images
# Processing 93 / 250 images
# Processing 94 / 250 images
# Processing 95 / 250 images
# Processing 96 / 250 images
# Processing 97 / 250 images
# Processing 98 / 250 images
# Processing 99 / 250 images
# Processing 100 / 250 images
# Processing 101 / 250 images
# Processing 102 / 250 images
# Processing 103 / 250 images
# Processing 104 / 250 images
# Processing 105 / 250 images
# Processing 106 / 250 images
# Processing 107 / 250 images
# Processing 108 / 250 images
# Processing 109 / 250 images
# Processing 110 / 250 images
# Processing 111 / 250 images
# Processing 112 / 250 images
# Processing 113 / 250 images
# Processing 114 / 250 images
# Processing 115 / 250 images
# Processing 116 / 250 images
# Processing 117 / 250 images
# Processing 118 / 250 images
# Processing 119 / 250 images
# Processing 120 / 250 images
# Processing 121 / 250 images
# Processing 122 / 250 images
# Processing 123 / 250 images
# Processing 124 / 250 images
# Processing 125 / 250 images
# Processing 126 / 250 images
# Processing 127 / 250 images
# Processing 128 / 250 images
# Processing 129 / 250 images
# Processing 130 / 250 images
# Processing 131 / 250 images
# Processing 132 / 250 images
# Processing 133 / 250 images
# Processing 134 / 250 images
# Processing 135 / 250 images
# Processing 136 / 250 images
# Processing 137 / 250 images
# Processing 138 / 250 images
# Processing 139 / 250 images
# Processing 140 / 250 images
# Processing 141 / 250 images
# Processing 142 / 250 images
# Processing 143 / 250 images
# Processing 144 / 250 images
# Processing 145 / 250 images
# Processing 146 / 250 images
# Processing 147 / 250 images
# Processing 148 / 250 images
# Processing 149 / 250 images
# Processing 150 / 250 images
# Processing 151 / 250 images
# Processing 152 / 250 images
# Processing 153 / 250 images
# Processing 154 / 250 images
# Processing 155 / 250 images
# Processing 156 / 250 images
# Processing 157 / 250 images
# Processing 158 / 250 images
# Processing 159 / 250 images
# Processing 160 / 250 images
# Processing 161 / 250 images
# Processing 162 / 250 images
# Processing 163 / 250 images
# Processing 164 / 250 images
# Processing 165 / 250 images
# Processing 166 / 250 images
# Processing 167 / 250 images
# Processing 168 / 250 images
# Processing 169 / 250 images
# Processing 170 / 250 images
# Processing 171 / 250 images
# Processing 172 / 250 images
# Processing 173 / 250 images
# Processing 174 / 250 images
# Processing 175 / 250 images
# Processing 176 / 250 images
# Processing 177 / 250 images
# Processing 178 / 250 images
# Processing 179 / 250 images
# Processing 180 / 250 images
# Processing 181 / 250 images
# Processing 182 / 250 images
# Processing 183 / 250 images
# Processing 184 / 250 images
# Processing 185 / 250 images
# Processing 186 / 250 images
# Processing 187 / 250 images
# Processing 188 / 250 images
# Processing 189 / 250 images
# Processing 190 / 250 images
# Processing 191 / 250 images
# Processing 192 / 250 images
# Processing 193 / 250 images
# Processing 194 / 250 images
# Processing 195 / 250 images
# Processing 196 / 250 images
# Processing 197 / 250 images
# Processing 198 / 250 images
# Processing 199 / 250 images
# Processing 200 / 250 images
# Processing 201 / 250 images
# Processing 202 / 250 images
# Processing 203 / 250 images
# Processing 204 / 250 images
# Processing 205 / 250 images
# Processing 206 / 250 images
# Processing 207 / 250 images
# Processing 208 / 250 images
# Processing 209 / 250 images
# Processing 210 / 250 images
# Processing 211 / 250 images
# Processing 212 / 250 images
# Processing 213 / 250 images
# Processing 214 / 250 images
# Processing 215 / 250 images
# Processing 216 / 250 images
# Processing 217 / 250 images
# Processing 218 / 250 images
# Processing 219 / 250 images
# Processing 220 / 250 images
# Processing 221 / 250 images
# Processing 222 / 250 images
# Processing 223 / 250 images
# Processing 224 / 250 images
# Processing 225 / 250 images
# Processing 226 / 250 images
# Processing 227 / 250 images
# Processing 228 / 250 images
# Processing 229 / 250 images
# Processing 230 / 250 images
# Processing 231 / 250 images
# Processing 232 / 250 images
# Processing 233 / 250 images
# Processing 234 / 250 images
# Processing 235 / 250 images
# Processing 236 / 250 images
# Processing 237 / 250 images
# Processing 238 / 250 images
# Processing 239 / 250 images
# Processing 240 / 250 images
# Processing 241 / 250 images
# Processing 242 / 250 images
# Processing 243 / 250 images
# Processing 244 / 250 images
# Processing 245 / 250 images
# Processing 246 / 250 images
# Processing 247 / 250 images
# Processing 248 / 250 images
# Processing 249 / 250 images
# Processing 250 / 250 images
#
# Processing label sunrise
# Processing 1 / 350 images
# Processing 2 / 350 images
# Processing 3 / 350 images
# Processing 4 / 350 images
# Processing 5 / 350 images
# Processing 6 / 350 images
# Processing 7 / 350 images
# Processing 8 / 350 images
# Processing 9 / 350 images
# Processing 10 / 350 images
# Processing 11 / 350 images
# Processing 12 / 350 images
# Processing 13 / 350 images
# Processing 14 / 350 images
# Processing 15 / 350 images
# Processing 16 / 350 images
# Processing 17 / 350 images
# Processing 18 / 350 images
# Processing 19 / 350 images
# Processing 20 / 350 images
# Processing 21 / 350 images
# Processing 22 / 350 images
# Processing 23 / 350 images
# Processing 24 / 350 images
# Processing 25 / 350 images
# Processing 26 / 350 images
# Processing 27 / 350 images
# Processing 28 / 350 images
# Processing 29 / 350 images
# Processing 30 / 350 images
# Processing 31 / 350 images
# Processing 32 / 350 images
# Processing 33 / 350 images
# Processing 34 / 350 images
# Processing 35 / 350 images
# Processing 36 / 350 images
# Processing 37 / 350 images
# Processing 38 / 350 images
# Processing 39 / 350 images
# Processing 40 / 350 images
# Processing 41 / 350 images
# Processing 42 / 350 images
# Processing 43 / 350 images
# Processing 44 / 350 images
# Processing 45 / 350 images
# Processing 46 / 350 images
# Processing 47 / 350 images
# Processing 48 / 350 images
# Processing 49 / 350 images
# Processing 50 / 350 images
# Processing 51 / 350 images
# Processing 52 / 350 images
# Processing 53 / 350 images
# Processing 54 / 350 images
# Processing 55 / 350 images
# Processing 56 / 350 images
# Processing 57 / 350 images
# Processing 58 / 350 images
# Processing 59 / 350 images
# Processing 60 / 350 images
# Processing 61 / 350 images
# Processing 62 / 350 images
# Processing 63 / 350 images
# Processing 64 / 350 images
# Processing 65 / 350 images
# Processing 66 / 350 images
# Processing 67 / 350 images
# Processing 68 / 350 images
# Processing 69 / 350 images
# Processing 70 / 350 images
# Processing 71 / 350 images
# Processing 72 / 350 images
# Processing 73 / 350 images
# Processing 74 / 350 images
# Processing 75 / 350 images
# Processing 76 / 350 images
# Processing 77 / 350 images
# Processing 78 / 350 images
# Processing 79 / 350 images
# Processing 80 / 350 images
# Processing 81 / 350 images
# Processing 82 / 350 images
# Processing 83 / 350 images
# Processing 84 / 350 images
# Processing 85 / 350 images
# Processing 86 / 350 images
# Processing 87 / 350 images
# Processing 88 / 350 images
# Processing 89 / 350 images
# Processing 90 / 350 images
# Processing 91 / 350 images
# Processing 92 / 350 images
# Processing 93 / 350 images
# Processing 94 / 350 images
# Processing 95 / 350 images
# Processing 96 / 350 images
# Processing 97 / 350 images
# Processing 98 / 350 images
# Processing 99 / 350 images
# Processing 100 / 350 images
# Processing 101 / 350 images
# Processing 102 / 350 images
# Processing 103 / 350 images
# Processing 104 / 350 images
# Processing 105 / 350 images
# Processing 106 / 350 images
# Processing 107 / 350 images
# Processing 108 / 350 images
# Processing 109 / 350 images
# Processing 110 / 350 images
# Processing 111 / 350 images
# Processing 112 / 350 images
# Processing 113 / 350 images
# Processing 114 / 350 images
# Processing 115 / 350 images
# Processing 116 / 350 images
# Processing 117 / 350 images
# Processing 118 / 350 images
# Processing 119 / 350 images
# Processing 120 / 350 images
# Processing 121 / 350 images
# Processing 122 / 350 images
# Processing 123 / 350 images
# Processing 124 / 350 images
# Processing 125 / 350 images
# Processing 126 / 350 images
# Processing 127 / 350 images
# Processing 128 / 350 images
# Processing 129 / 350 images
# Processing 130 / 350 images
# Processing 131 / 350 images
# Processing 132 / 350 images
# Processing 133 / 350 images
# Processing 134 / 350 images
# Processing 135 / 350 images
# Processing 136 / 350 images
# Processing 137 / 350 images
# Processing 138 / 350 images
# Processing 139 / 350 images
# Processing 140 / 350 images
# Processing 141 / 350 images
# Processing 142 / 350 images
# Processing 143 / 350 images
# Processing 144 / 350 images
# Processing 145 / 350 images
# Processing 146 / 350 images
# Processing 147 / 350 images
# Processing 148 / 350 images
# Processing 149 / 350 images
# Processing 150 / 350 images
# Processing 151 / 350 images
# Processing 152 / 350 images
# Processing 153 / 350 images
# Processing 154 / 350 images
# Processing 155 / 350 images
# Processing 156 / 350 images
# Processing 157 / 350 images
# Processing 158 / 350 images
# Processing 159 / 350 images
# Processing 160 / 350 images
# Processing 161 / 350 images
# Processing 162 / 350 images
# Processing 163 / 350 images
# Processing 164 / 350 images
# Processing 165 / 350 images
# Processing 166 / 350 images
# Processing 167 / 350 images
# Processing 168 / 350 images
# Processing 169 / 350 images
# Processing 170 / 350 images
# Processing 171 / 350 images
# Processing 172 / 350 images
# Processing 173 / 350 images
# Processing 174 / 350 images
# Processing 175 / 350 images
# Processing 176 / 350 images
# Processing 177 / 350 images
# Processing 178 / 350 images
# Processing 179 / 350 images
# Processing 180 / 350 images
# Processing 181 / 350 images
# Processing 182 / 350 images
# Processing 183 / 350 images
# Processing 184 / 350 images
# Processing 185 / 350 images
# Processing 186 / 350 images
# Processing 187 / 350 images
# Processing 188 / 350 images
# Processing 189 / 350 images
# Processing 190 / 350 images
# Processing 191 / 350 images
# Processing 192 / 350 images
# Processing 193 / 350 images
# Processing 194 / 350 images
# Processing 195 / 350 images
# Processing 196 / 350 images
# Processing 197 / 350 images
# Processing 198 / 350 images
# Processing 199 / 350 images
# Processing 200 / 350 images
# Processing 201 / 350 images
# Processing 202 / 350 images
# Processing 203 / 350 images
# Processing 204 / 350 images
# Processing 205 / 350 images
# Processing 206 / 350 images
# Processing 207 / 350 images
# Processing 208 / 350 images
# Processing 209 / 350 images
# Processing 210 / 350 images
# Processing 211 / 350 images
# Processing 212 / 350 images
# Processing 213 / 350 images
# Processing 214 / 350 images
# Processing 215 / 350 images
# Processing 216 / 350 images
# Processing 217 / 350 images
# Processing 218 / 350 images
# Processing 219 / 350 images
# Processing 220 / 350 images
# Processing 221 / 350 images
# Processing 222 / 350 images
# Processing 223 / 350 images
# Processing 224 / 350 images
# Processing 225 / 350 images
# Processing 226 / 350 images
# Processing 227 / 350 images
# Processing 228 / 350 images
# Processing 229 / 350 images
# Processing 230 / 350 images
# Processing 231 / 350 images
# Processing 232 / 350 images
# Processing 233 / 350 images
# Processing 234 / 350 images
# Processing 235 / 350 images
# Processing 236 / 350 images
# Processing 237 / 350 images
# Processing 238 / 350 images
# Processing 239 / 350 images
# Processing 240 / 350 images
# Processing 241 / 350 images
# Processing 242 / 350 images
# Processing 243 / 350 images
# Processing 244 / 350 images
# Processing 245 / 350 images
# Processing 246 / 350 images
# Processing 247 / 350 images
# Processing 248 / 350 images
# Processing 249 / 350 images
# Processing 250 / 350 images
# Processing 251 / 350 images
# Processing 252 / 350 images
# Processing 253 / 350 images
# Processing 254 / 350 images
# Processing 255 / 350 images
# Processing 256 / 350 images
# Processing 257 / 350 images
# Processing 258 / 350 images
# Processing 259 / 350 images
# Processing 260 / 350 images
# Processing 261 / 350 images
# Processing 262 / 350 images
# Processing 263 / 350 images
# Processing 264 / 350 images
# Processing 265 / 350 images
# Processing 266 / 350 images
# Processing 267 / 350 images
# Processing 268 / 350 images
# Processing 269 / 350 images
# Processing 270 / 350 images
# Processing 271 / 350 images
# Processing 272 / 350 images
# Processing 273 / 350 images
# Processing 274 / 350 images
# Processing 275 / 350 images
# Processing 276 / 350 images
# Processing 277 / 350 images
# Processing 278 / 350 images
# Processing 279 / 350 images
# Processing 280 / 350 images
# Processing 281 / 350 images
# Processing 282 / 350 images
# Processing 283 / 350 images
# Processing 284 / 350 images
# Processing 285 / 350 images
# Processing 286 / 350 images
# Processing 287 / 350 images
# Processing 288 / 350 images
# Processing 289 / 350 images
# Processing 290 / 350 images
# Processing 291 / 350 images
# Processing 292 / 350 images
# Processing 293 / 350 images
# Processing 294 / 350 images
# Processing 295 / 350 images
# Processing 296 / 350 images
# Processing 297 / 350 images
# Processing 298 / 350 images
# Processing 299 / 350 images
# Processing 300 / 350 images
# Processing 301 / 350 images
# Processing 302 / 350 images
# Processing 303 / 350 images
# Processing 304 / 350 images
# Processing 305 / 350 images
# Processing 306 / 350 images
# Processing 307 / 350 images
# Processing 308 / 350 images
# Processing 309 / 350 images
# Processing 310 / 350 images
# Processing 311 / 350 images
# Processing 312 / 350 images
# Processing 313 / 350 images
# Processing 314 / 350 images
# Processing 315 / 350 images
# Processing 316 / 350 images
# Processing 317 / 350 images
# Processing 318 / 350 images
# Processing 319 / 350 images
# Processing 320 / 350 images
# Processing 321 / 350 images
# Processing 322 / 350 images
# Processing 323 / 350 images
# Processing 324 / 350 images
# Processing 325 / 350 images
# Processing 326 / 350 images
# Processing 327 / 350 images
# Processing 328 / 350 images
# Processing 329 / 350 images
# Processing 330 / 350 images
# Processing 331 / 350 images
# Processing 332 / 350 images
# Processing 333 / 350 images
# Processing 334 / 350 images
# Processing 335 / 350 images
# Processing 336 / 350 images
# Processing 337 / 350 images
# Processing 338 / 350 images
# Processing 339 / 350 images
# Processing 340 / 350 images
# Processing 341 / 350 images
# Processing 342 / 350 images
# Processing 343 / 350 images
# Processing 344 / 350 images
# Processing 345 / 350 images
# Processing 346 / 350 images
# Processing 347 / 350 images
# Processing 348 / 350 images
# Processing 349 / 350 images
# Processing 350 / 350 images
#                          img_path       avg_r       avg_g       avg_b  \
# 0  ./dataset/cloudy/cloudy168.jpg   87.076080   91.337559   96.500416
# 1   ./dataset/cloudy/cloudy87.jpg  104.670648  113.177775  127.331482
# 2  ./dataset/cloudy/cloudy141.jpg  116.599169  130.515403  150.623516
# 3  ./dataset/cloudy/cloudy274.jpg  134.550592  137.921905  131.195361
# 4  ./dataset/cloudy/cloudy273.jpg  123.177525  128.685279  136.836869
#
#       avg_s    contrast       ASM  homogeneity type_label
# 0  0.132656    6.308549  0.003071     0.619131     cloudy
# 1  0.209552   17.488994  0.002722     0.594842     cloudy
# 2  0.294946  511.862221  0.000795     0.256738     cloudy
# 3  0.163266    4.876999  0.002610     0.604593     cloudy
# 4  0.103191   12.654950  0.001312     0.427159     cloudy

# %%
test_label_map = {
    "cloud" : "cloudy",
    "foggy" : "foggy",
    "rain" : "rainy",
    "shine" : "shine",
    "sunrise" : "sunrise"
}
test_df = generate_test("./dataset/", "alien_test/*", test_label_map)

display(test_df)
test_df.to_csv("test_images_features.csv", index_label="id")
# Out:
# Processing 1 / 30 images
# Processing 2 / 30 images
# Processing 3 / 30 images
# Processing 4 / 30 images
# Processing 5 / 30 images
# Processing 6 / 30 images
# Processing 7 / 30 images
# Processing 8 / 30 images
# Processing 9 / 30 images
# Processing 10 / 30 images
# Processing 11 / 30 images
# Processing 12 / 30 images
# Processing 13 / 30 images
# Processing 14 / 30 images
# Processing 15 / 30 images
# Processing 16 / 30 images
# Processing 17 / 30 images
# Processing 18 / 30 images
# Processing 19 / 30 images
# Processing 20 / 30 images
# Processing 21 / 30 images
# Processing 22 / 30 images
# Processing 23 / 30 images
# Processing 24 / 30 images
# Processing 25 / 30 images
# Processing 26 / 30 images
# Processing 27 / 30 images
# Processing 28 / 30 images
# Processing 29 / 30 images
# Processing 30 / 30 images
#                               img_path       avg_r       avg_g       avg_b  \
# 0      ./dataset/alien_test/rain_1.jpg   89.380456  108.331348   92.704043
# 1     ./dataset/alien_test/shine_1.jpg   84.179988  145.610668  202.758774
# 2     ./dataset/alien_test/foggy_5.jpg  111.901819  122.010252  123.489308
# 3     ./dataset/alien_test/Cloud_4.jpg   88.340293  151.776627  193.868678
# 4     ./dataset/alien_test/foggy_7.jpg  122.728178   73.513052   36.486659
# 5   ./dataset/alien_test/sunrise_5.jpg  111.447737   64.423823   46.635379
# 6     ./dataset/alien_test/foggy_3.jpg  120.045989  102.307547   83.251539
# 7     ./dataset/alien_test/shine_3.jpg  137.931860  178.009487  215.315102
# 8    ./dataset/alien_test/foggy_10.jpg  132.539126  132.405096  126.782115
# 9     ./dataset/alien_test/foggy_1.jpg   66.398060   80.541773   67.158103
# 10    ./dataset/alien_test/foggy_8.jpg  103.338040  118.942280  164.395469
# 11    ./dataset/alien_test/foggy_6.jpg  147.343894  150.666864  148.089349
# 12     ./dataset/alien_test/rain_2.png   77.226120   72.299090   70.990504
# 13  ./dataset/alien_test/sunrise_1.jpg  189.254008  118.666052   74.137540
# 14   ./dataset/alien_test/Cloud_3.jpeg  153.134185  180.993051  211.830939
# 15  ./dataset/alien_test/sunrise_7.jpg   95.225713   88.193064   74.347746
# 16    ./dataset/alien_test/foggy_4.jpg   88.333931   89.177541   93.578549
# 17    ./dataset/alien_test/Cloud_1.png  163.492459  165.819356  170.520993
# 18  ./dataset/alien_test/sunrise_3.jpg  146.154150  101.673953   80.119714
# 19     ./dataset/alien_test/rain_6.jpg   37.964613   45.651802   46.328414
# 20     ./dataset/alien_test/rain_4.jpg  113.858698  132.261125  147.834904
# 21  ./dataset/alien_test/sunrise_2.jpg   69.331525   53.887872   45.157163
# 22    ./dataset/alien_test/Cloud_2.jpg  154.442258  154.442258  154.442258
# 23     ./dataset/alien_test/rain_5.jpg  133.457214  132.698459  134.916249
# 24  ./dataset/alien_test/sunrise_4.jpg   96.370680   86.159544   70.650595
# 25    ./dataset/alien_test/foggy_9.jpg  142.793010  145.073351  145.749256
# 26  ./dataset/alien_test/sunrise_6.jpg   75.373740   49.682540   34.802827
# 27    ./dataset/alien_test/foggy_2.jpg   63.519059   71.312428   77.386192
# 28    ./dataset/alien_test/shine_2.jpg   53.358414  123.017705  162.613907
# 29     ./dataset/alien_test/rain_3.jpg  147.033529  144.461005  146.803162
#
#        avg_s    contrast       ASM  homogeneity type_label
# 0   0.340140  104.245269  0.001284     0.284216      rainy
# 1   0.650524   25.325296  0.003029     0.637173      shine
# 2   0.122873   11.677350  0.002500     0.705304      foggy
# 3   0.557622   17.755358  0.002650     0.506353     cloudy
# 4   0.714519    8.337532  0.003289     0.732819      foggy
# 5   0.712069  151.411200  0.000367     0.250481    sunrise
# 6   0.302281   11.199281  0.001511     0.413310      foggy
# 7   0.363824   12.915281  0.003435     0.638476      shine
# 8   0.110793   11.561278  0.002380     0.649980      foggy
# 9   0.260730   12.427625  0.001643     0.550861      foggy
# 10  0.414320   38.657443  0.002188     0.606956      foggy
# 11  0.051387   18.912903  0.003552     0.755690      foggy
# 12  0.153386  420.121074  0.000338     0.151414      rainy
# 13  0.692212   32.759257  0.001151     0.470572    sunrise
# 14  0.282064    6.356457  0.001823     0.592882     cloudy
# 15  0.255558   21.646752  0.006966     0.632498    sunrise
# 16  0.054974    1.232996  0.006803     0.844531      foggy
# 17  0.107276    3.370411  0.002485     0.688930     cloudy
# 18  0.549432  501.561586  0.000566     0.332489    sunrise
# 19  0.492872  318.311747  0.015745     0.386684      rainy
# 20  0.281479  207.871579  0.000150     0.129199      rainy
# 21  0.381271   29.985555  0.018007     0.509632    sunrise
# 22  0.000000    6.389754  0.001511     0.592868     cloudy
# 23  0.075735  100.620595  0.002471     0.354184      rainy
# 24  0.356821   15.908794  0.003281     0.580498    sunrise
# 25  0.064371   80.952795  0.002629     0.636292      foggy
# 26  0.534158    6.637481  0.005450     0.628139    sunrise
# 27  0.296961   34.651318  0.002288     0.539395      foggy
# 28  0.708537   25.889486  0.002633     0.576582      shine
# 29  0.125955  153.057811  0.000174     0.161526      rainy
